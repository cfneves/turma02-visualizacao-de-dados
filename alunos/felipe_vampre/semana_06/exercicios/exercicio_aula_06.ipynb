# %%
import pandas as pd
import numpy as np


df = pd.read_excel("../base/base_vendas_supermercado.xlsx")

print(f"Linhas: {df.shape[0]} | Colunas: {df.shape[1]}")
# Out:
# Linhas: 250 | Colunas: 12
# /home/vampre/Ubuntu Projetos/sctec/turma-visualizacao-de-dados/.venv/lib/python3.12/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
# /home/vampre/Ubuntu Projetos/sctec/turma-visualizacao-de-dados/.venv/lib/python3.12/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Conditional Formatting extension is not supported and will be removed
#   warn(msg)
