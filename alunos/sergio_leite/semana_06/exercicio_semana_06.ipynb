# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_excel(r"C:\turma-visualizacao-de-dados\alunos\sergio_leite\semana_06\base_vendas_supermercado.xlsx") # colocar o R
print("Sucesso!")
# Out:
# Sucesso!
# C:\Users\android\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
# C:\Users\android\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Conditional Formatting extension is not supported and will be removed
#   warn(msg)

# %%
# df.head()
# df.tail()

print()
print(f' O DF possui {df.shape[0]} Linhas')
print(f' O DF possui {df.shape[1]} Colunas')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Data                250 non-null    datetime64[ns]
#  1   Loja                250 non-null    object
#  2   Cliente             250 non-null    object
#  3   Categoria           250 non-null    object
#  4   Produto             250 non-null    object
#  5   Quantidade          250 non-null    int64
#  6   Preço Unitário      250 non-null    float64
#  7   Desconto %          250 non-null    float64
#  8   Valor Bruto         250 non-null    float64
#  9   Valor Desconto      250 non-null    float64
#  10  Valor Líquido       250 non-null    float64
#  11  Forma de Pagamento  250 non-null    object
# dtypes: datetime64[ns](1), float64(5), int64(1), object(5)
# memory usage: 23.6+ KB

# %%
# Insira 10 NaN em `'Categoria'` e 8 NaN em `'Quantidade'`
# Insira 5 valores absurdos em `'Valor Líquido'` (ex: R$ 5000, R$ 0.01)
# Duplique 7 linhas aleatórias
