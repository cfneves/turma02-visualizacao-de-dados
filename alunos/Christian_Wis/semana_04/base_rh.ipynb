# %%
import pandas as pd
import re
from datetime import datetime

# %%
# confirmar que as importações fucionaram
print('pandas versão:', pd.__version__)
print('bibliotecas importadas com sucesso!')
# Out:
#  pandas versão: 3.0.2
#  Bibliotecas importadas com sucesso!

# %%
caminho = r"C:\Users\s2bcl\OneDrive\Documents\Lab365\aula_de_hoje\turma-visualizacao-de-dados\alunos\Christian_wis\semana_04\base_rh.csv"

df = pd.read_csv(
    caminho,
    sep=';',
    enconding='utf-8',
    decimal=','
)

print('Dados carregados com sucesso!!!')
print(f'total de linhas: {df.shape[0]}')
print(f'total de colunas: {df.shape[1]}')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 caminho = r"C:\Users\s2bcl\OneDrive\Documents\Lab365\aula_de_hoje\turma-visualizacao-de-dados\alunos\Christian_wis\semana_04\base_rh.csv"
#       2
# ----> 3 df = pd.read_csv(
#       4     caminho,
#       5     sep=';',
#       6     enconding='utf-8',
#
# TypeError: read_csv() got an unexpected keyword argument 'enconding'. Did you mean 'encoding'?
