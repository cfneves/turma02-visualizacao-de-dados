# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_excel("../base/base_vendas_supermercado.xlsx")
df.head() # Adicione isso para visualizar as primeiras 5 linhas do Excel
# Out:
# c:\Users\Milla\AppData\Local\Programs\Python\Python313\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
# c:\Users\Milla\AppData\Local\Programs\Python\Python313\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Conditional Formatting extension is not supported and will be removed
#   warn(msg)
#         Data           Loja           Cliente   Categoria  \
# 0 2026-01-04  Loja Shopping     Cliente Final  Laticínios
# 1 2026-01-04    Loja Centro  Clube Fidelidade   Mercearia
# 2 2026-02-27  Loja Shopping  Clube Fidelidade     Padaria
# 3 2026-01-12     Loja Norte     Cliente Final  Laticínios
# 4 2026-05-05     Loja Norte  Clube Fidelidade  Laticínios
#
#                  Produto  Quantidade  Preço Unitário  Desconto %  Valor Bruto  \
# 0  Queijo Mussarela 500g           4           23.53        0.00        94.12
# ...
