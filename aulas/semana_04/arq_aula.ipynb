# %%
["Endereco": {   
    "rua": "Rua dos Bobos",
    "numero": 0,
    "cidade": "São Paulo",
    "estado": "SP"
}]
# Out:
#   Cell In[15], line 1
#     ["Endereco": {
#                ^
# SyntaxError: invalid syntax

# %%
{
    "nome": "claudio",
    "idade": 30,
    "ativo": True

}
# Out:
# {'nome': 'claudio', 'idade': 30, 'ativo': True}
